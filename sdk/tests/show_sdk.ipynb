# %% [markdown]
# ### Demo muy simple del SDK | Very simple SDK demo

# %%
from air_travel import AsyncAirTravelClient

client = AsyncAirTravelClient(
    base_url="http://127.0.0.1:8000/")

# %%
flights = await client.flights(limit=5)

print(flights)
# Out:
# [{'flight_date': '2025-11-12', 'iata_code_marketing_airline': 'UA', 'flight_number_marketing_airline': '4712', 'origin': 'ORD', 'origin_city_name': 'Chicago, IL', 'dest': 'ELP', 'dest_city_name': 'El Paso, TX', 'crs_dep_time': '2005', 'dep_time': '2004', 'crs_arr_time': '2253', 'arr_time': '2313', 'dep_delay_minutes': 0.0, 'arr_delay_minutes': 20.0, 'cancelled': 0.0, 'diverted': 0.0, 'operating_airline': 'OO', 'iata_code_operating_airline': 'OO', 'tail_number': 'N135SY', 'id': 1}, {'flight_date': '2025-11-12', 'iata_code_marketing_airline': 'UA', 'flight_number_marketing_airline': '4713', 'origin': 'MRY', 'origin_city_name': 'Monterey, CA', 'dest': 'DEN', 'dest_city_name': 'Denver, CO', 'crs_dep_time': '1235', 'dep_time': '1228', 'crs_arr_time': '1620', 'arr_time': '1548', 'dep_delay_minutes': 0.0, 'arr_delay_minutes': 0.0, 'cancelled': 0.0, 'diverted': 0.0, 'operating_airline': 'OO', 'iata_code_operating_airline': 'OO', 'tail_number': 'N87364', 'id': 2}, {'flight_date': '2025-11-12'
# ...

# %%
airlines = await client.airlines()
print(airlines)
# Out:
# [{'carrier': 'AA', 'carrier_name': 'American Airlines'}, {'carrier': 'DL', 'carrier_name': 'Delta Air Lines'}, {'carrier': 'UA', 'carrier_name': 'United Airlines'}, {'carrier': 'WN', 'carrier_name': 'Southwest Airlines'}]
